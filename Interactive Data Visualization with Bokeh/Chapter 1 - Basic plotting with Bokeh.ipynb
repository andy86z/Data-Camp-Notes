# %% [markdown]
# # Interactive Data Visualization with Bokeh
# ##### Course Description
# Bokeh is an interactive data visualization library for Python (and other languages!) that targets modern web browsers for presentation. It can create versatile, data-driven graphics, and connect the full power of the entire Python data-science stack to rich, interactive visualizations.
#
# ### Chapter 1: Basic plotting with Bokeh
# An introduction to basic plotting with Bokeh. You will create your first plots, learn about different data formats Bokeh understands, and make visual customizations for selections and mouse hovering.

# %% [markdown]
# # A simple scatter plot
# In this example, you're going to make a scatter plot of female literacy vs fertility using data from the European Environmental Agency. This dataset highlights that countries with low female literacy have high birthrates. The x-axis data has been loaded for you as fertility and the y-axis data has been loaded as female_literacy.
#
# Your job is to create a figure, assign x-axis and y-axis labels, and plot female_literacy vs fertility using the circle glyph.
#
# After you have created the figure, in this exercise and the ones to follow, play around with it! Explore the different options available to you on the tab to the right, such as "Pan", "Box Zoom", and "Wheel Zoom". You can click on the question mark sign for more details on any of these tools.
#
# Note: You may have to scroll down to view the lower portion of the figure.
#
# ### Instructions
# * Import the figure function from bokeh.plotting, and the output_file and show functions from bokeh.io.
# * Create the figure p with figure(). It has two parameters: x_axis_label and y_axis_label.
# * Add a circle glyph to the figure p using the function p.circle() where the inputs are, in order, the x-axis data and y-axis data.
# * Use the output_file() function to specify the name 'fert_lit.html' for the output file.
# * Create and display the output file using show() and passing in the figure p.

# %%
fertility = [1.7690000000000001, 2.682, 2.077, 2.1319999999999997, 1.827, 3.872, 2.2880000000000003, 5.172999999999999, 1.393, 1.262, 2.156, 3.0260000000000002, 2.033, 1.324, 2.8160000000000003, 5.211, 2.1, 1.781, 1.8219999999999998, 5.9079999999999995, 1.881, 1.8519999999999999, 1.39, 2.281, 2.505, 1.224, 1.361, 1.4680000000000002, 2.404, 5.52, 4.058, 2.2230000000000003, 4.859, 1.2670000000000001, 2.342, 1.579, 6.254, 2.334, 3.9610000000000003, 6.505, 2.53, 2.823, 2.498, 2.248, 2.508, 3.04, 1.854, 4.22, 5.1, 4.967, 1.325, 4.513999999999999, 3.173, 2.3080000000000003, 4.62, 4.541, 5.6370000000000005, 1.926, 1.7469999999999999, 2.294, 5.841, 5.455, 7.069, 2.859, 4.018, 2.513, 5.405, 5.737, 3.363, 4.89, 1.385, 1.505, 6.081, 1.784, 1.3780000000000001, 1.45, 1.841, 1.37, 2.612, 5.329, 5.33, 3.3710000000000004, 1.281, 1.871, 2.153, 5.377999999999999, 4.45, 1.46, 1.436, 1.6119999999999999, 3.19, 2.752, 3.35, 4.01, 4.166, 2.642, 2.977, 3.415, 2.295, 3.0189999999999997, 2.6830000000000003, 5.165, 1.849, 1.8359999999999999, 2.5180000000000002, 2.43, 4.5280000000000005, 1.263, 1.885, 1.943, 1.899, 1.442, 1.953, 4.697, 1.5819999999999999, 2.025, 1.841, 5.011, 1.212, 1.5019999999999998, 2.516, 1.367, 2.089, 4.388, 1.854, 1.7480000000000002, 2.978, 2.1519999999999997, 2.362, 1.9880000000000002, 1.426, 3.29, 3.264, 1.436, 1.393, 2.822, 4.968999999999999, 5.659, 3.24, 1.693, 1.6469999999999998, 2.36, 1.7919999999999998, 3.45, 1.516, 2.233, 2.563, 5.2829999999999995, 3.885, 0.966, 2.373, 2.6630000000000003, 1.251, 2.052, 3.3710000000000004, 2.093, 2.0, 3.883, 3.852, 3.718, 1.732, 3.928]
female_literacy = [90.5, 50.8, 99.0, 88.8, 90.2, 40.0, 49.8, 48.8, 99.4, 99.0, 91.5, 93.9, 90.2, 99.0, 57.8, 22.8, 81.3, 77.2, 91.5, 56.1, 99.0, 99.0, 98.5, 89.2, 88.1, 96.6, 99.6, 96.9, 93.4, 66.3, 59.6, 97.7, 82.8, 99.3, 63.9, 99.0, 66.8, 44.1, 69.2, 12.6, 84.6, 45.4, 94.9, 98.9, 89.8, 80.2, 100.0, 59.3, 42.8, 40.1, 96.9, 44.3, 77.2, 89.1, 65.3, 67.8, 57.0, 98.7, 99.0, 99.5, 21.6, 65.8, 15.1, 70.9, 68.7, 81.7, 18.2, 61.0, 88.8, 33.0, 95.9, 99.8, 21.9, 99.0, 92.9, 99.0, 71.0, 98.9, 88.3, 26.4, 66.1, 86.0, 99.7, 99.0, 99.2, 28.1, 59.9, 99.0, 97.9, 96.2, 83.5, 95.9, 99.5, 55.6, 53.7, 81.3, 93.5, 63.2, 81.4, 88.9, 77.9, 28.9, 99.0, 100.0, 99.1, 99.3, 54.5, 91.6, 100.0, 96.2, 91.5, 98.0, 99.0, 41.1, 99.7, 99.0, 86.0, 53.0, 95.9, 97.8, 92.8, 99.7, 98.5, 49.5, 98.7, 99.4, 80.9, 93.1, 90.8, 97.8, 99.8, 87.7, 95.1, 95.4, 99.7, 83.5, 34.3, 36.5, 83.2, 99.8, 98.2, 90.4, 84.8, 85.6, 96.7, 89.4, 38.7, 89.1, 67.8, 90.7, 88.4, 79.3, 93.5, 93.3, 96.5, 99.0, 98.4, 79.5, 98.5, 83.3, 98.0, 99.1]

fertility_africa = [5.172999999999999, 2.8160000000000003, 5.211, 5.9079999999999995, 2.505, 5.52, 4.058, 4.859, 2.342, 6.254, 2.334, 4.22, 4.967, 4.513999999999999, 4.62, 4.541, 5.6370000000000005, 5.841, 5.455, 7.069, 5.405, 5.737, 3.363, 4.89, 6.081, 1.841, 5.329, 5.33, 5.377999999999999, 4.45, 4.166, 2.642, 5.165, 4.5280000000000005, 4.697, 5.011, 4.388, 3.29, 3.264, 2.822, 4.968999999999999, 5.659, 3.24, 1.7919999999999998, 3.45, 5.2829999999999995, 3.885, 2.6630000000000003, 3.718]
female_literacy_africa = [48.8, 57.8, 22.8, 56.1, 88.1, 66.3, 59.6, 82.8, 63.9, 66.8, 44.1, 59.3, 40.1, 44.3, 65.3, 67.8, 57.0, 21.6, 65.8, 15.1, 18.2, 61.0, 88.8, 33.0, 21.9, 71.0, 26.4, 66.1, 28.1, 59.9, 53.7, 81.3, 28.9, 54.5, 41.1, 53.0, 49.5, 87.7, 95.1, 83.5, 34.3, 36.5, 83.2, 84.8, 85.6, 89.1, 67.8, 79.3, 83.3]

fertility_latinamerica = [1.827, 2.156, 2.404, 2.2230000000000003, 2.53, 2.498, 1.926, 4.018, 2.513, 1.505, 2.612, 3.3710000000000004, 3.19, 2.977, 2.295, 2.6830000000000003, 1.943, 2.516, 2.089, 2.362, 1.6469999999999998, 2.373, 3.3710000000000004, 1.732]
female_literacy_latinamerica = [90.2, 91.5, 93.4, 97.7, 84.6, 94.9, 98.7, 68.7, 81.7, 99.8, 88.3, 86.0, 83.5, 93.5, 81.4, 77.9, 96.2, 92.8, 98.5, 90.8, 98.2, 88.4, 96.5, 98.0]

# %%
# Import figure from bokeh.plotting
from bokeh.plotting import figure

# Import output_file and show from bokeh.io  NOTE: output_notebook is for Jupyter notebooks
from bokeh.io import output_notebook, show

# Create the figure: p
p = figure(x_axis_label='fertility (children per woman)', y_axis_label='female_literacy (% population)')

# Add a circle glyph to the figure p
p.circle(fertility, female_literacy)
# Look below for additional shapes to plot. Look at the Markers section.

# Call the output_file() function and specify the name of the file
output_notebook()

# Display the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="076ecd4d-834d-4377-847c-f5a6b8ea30b1">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0d68306a-a7b3-4a79-bf58-ca6d3ba95047"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0d68306a-a7b3-4a79-bf58-ca6d3ba95047");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0d68306a-a7b3-4a79-bf58-ca6d3ba95047");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0d68306a-a7b3-4a79-bf58-ca6d3ba95047' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"32ae83e8-86a7-4179-99f5-6314a6b73567":{"roots":{"references":[{"attributes":{"plot":{"id":"1881036a-c0f8-4712-99fc-737fb2bb004d","subtype":"Figure","type":"Plot"}},"id":"bff7b794-12ae-4bdc-90db-5677d78e92e8","type":"PanTool"},{"attributes":{"plot":{"id":"1881036a-c0f8-4712-99fc-737fb2bb004d","subtype":"Figure","type":"Plot"}},"id":"3280ee10-97b3-4d6d-893a-dbc1695309c0","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"7b805b99-7bba-4231-88ad-6b9a4762fdf3","type":"DataRange1d"},{"attributes":{"overlay":{"id":"fc1f9688-987d-4d91-8d98-e2d634ada525","type":"BoxAnnotation"},"plot":{"id":"1881036a-c0f8-4712-99fc-737fb2bb004d","subtype":"Figure","type":"Plot"}},"id":"3cc123e4-36a0-4565-b623-19389529aeb9","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"1881036a-c0f8-4712-99fc-737fb2bb004d","subtype":"Figure","type":"Plot"}},"id":"27b152e8-7401-4141-9053-7e6b2499b06e","type":"SaveTool"},{"attributes":{"plot":{"id":"1881036a-c0f8-4712-99fc-737fb2bb004d","subtype":"Figure","type":"Plot"}},"id":"f168fe08-9557-4d8c-a2de-839b7852020f","type":"ResetTool"},{"attributes":{"plot":{"id":"1881036a-c0f8-4712-99fc-737fb2bb004d","subtype":"Figure","type":"Plot"}},"id":"8e74598f-b692-4af8-a4af-c55f3611a08c","type":"HelpTool"},{"attributes":{"data_source":{"id":"5d5a67cd-26a3-4450-bd9f-5e326fb4ae9c","type":"ColumnDataSource"},"glyph":{"id":"1d8e8b05-4dd1-46a0-b878-5932262964dd","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8f07939b-c200-4c3e-a6fd-6aecd9fd96f4","type":"Circle"},"selection_glyph":null},"id":"941b7478-3e9b-479f-8d4d-396a6458444d","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8f07939b-c200-4c3e-a6fd-6aecd9fd96f4","type":"Circle"},{"attributes":{"plot":null,"text":""},"id":"e3a50bff-7862-4a11-ad4c-7d272097ae03","type":"Title"},{"attributes":{"axis_label":"fertility (children per woman)","formatter":{"id":"83b7d8fa-fec2-43f5-854d-26170aca4912","type":"BasicTickFormatter"},"plot":{"id":"1881036a-c0f8-4712-99fc-737fb2bb004d","subtype":"Figure","type":"Plot"},"ticker":{"id":"02b754de-69ac-4220-b79e-b8d602d931cf","type":"BasicTicker"}},"id":"d9569b60-6118-4e9d-a97a-295e8b754a1f","type":"LinearAxis"},{"attributes":{},"id":"a52fc2d4-a832-4693-bba6-80a03dacc85c","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"fc1f9688-987d-4d91-8d98-e2d634ada525","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1d8e8b05-4dd1-46a0-b878-5932262964dd","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1.7690000000000001,2.682,2.077,2.1319999999999997,1.827,3.872,2.2880000000000003,5.172999999999999,1.393,1.262,2.156,3.0260000000000002,2.033,1.324,2.8160000000000003,5.211,2.1,1.781,1.8219999999999998,5.9079999999999995,1.881,1.8519999999999999,1.39,2.281,2.505,1.224,1.361,1.4680000000000002,2.404,5.52,4.058,2.2230000000000003,4.859,1.2670000000000001,2.342,1.579,6.254,2.334,3.9610000000000003,6.505,2.53,2.823,2.498,2.248,2.508,3.04,1.854,4.22,5.1,4.967,1.325,4.513999999999999,3.173,2.3080000000000003,4.62,4.541,5.6370000000000005,1.926,1.7469999999999999,2.294,5.841,5.455,7.069,2.859,4.018,2.513,5.405,5.737,3.363,4.89,1.385,1.505,6.081,1.784,1.3780000000000001,1.45,1.841,1.37,2.612,5.329,5.33,3.3710000000000004,1.281,1.871,2.153,5.377999999999999,4.45,1.46,1.436,1.6119999999999999,3.19,2.752,3.35,4.01,4.166,2.642,2.977,3.415,2.295,3.0189999999999997,2.6830000000000003,5.165,1.849,1.8359999999999999,2.5180000000 ...

# %% [markdown]
# ### *Markers*
# * asterisk()
# * circle()
# * circle_cross()
# * circle_x()
# * cross()
# * diamond()
# * diamond_cross()
# * inverted_triangle()
# * square()
# * square_cross()
# * square_x()
# * triangle()
# * x()

# %%
# Glyph properties
# ● Lists, arrays, sequences of values
# ● Single fixed values
plot = figure()
plot.diamond_cross(x=10, y=[2,5,8,12], size=[10,20,30,40])
output_notebook()
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="26ac52ca-816e-4c2a-bc31-eb110e319ac3">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="497e13c5-90be-4e41-86d7-40b4537f6656"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("497e13c5-90be-4e41-86d7-40b4537f6656");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("497e13c5-90be-4e41-86d7-40b4537f6656");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '497e13c5-90be-4e41-86d7-40b4537f6656' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f24fc2d7-aed7-499c-aebb-08163afbbaf1":{"roots":{"references":[{"attributes":{"plot":{"id":"15f7a887-8185-49ae-b22b-706b8d20307d","subtype":"Figure","type":"Plot"}},"id":"4655bda9-e590-4de4-af7f-614def640098","type":"HelpTool"},{"attributes":{},"id":"b91ad1cb-ad74-425a-b98b-f035d2c8db32","type":"ToolEvents"},{"attributes":{"below":[{"id":"f269bd27-b637-44ae-bcbc-066143e0a29a","type":"LinearAxis"}],"left":[{"id":"1b340510-e0b7-481c-a8d9-d3c10f0c0788","type":"LinearAxis"}],"renderers":[{"id":"f269bd27-b637-44ae-bcbc-066143e0a29a","type":"LinearAxis"},{"id":"f7c847b2-72c3-4eb9-b8e5-9935d8a3716d","type":"Grid"},{"id":"1b340510-e0b7-481c-a8d9-d3c10f0c0788","type":"LinearAxis"},{"id":"c23187e6-a4d5-4a0d-a108-dda9ca1821fe","type":"Grid"},{"id":"c36ed490-0015-4db0-a031-42187896644b","type":"BoxAnnotation"},{"id":"3e11e8f1-b4dd-4073-a3b9-f17c6119d9bc","type":"GlyphRenderer"}],"title":{"id":"31d71247-fd88-4571-9693-2bc5354a5fc5","type":"Title"},"tool_events":{"id":"b91ad1cb-ad74-425a-b98b-f035d2c8db32","type":"ToolEvents"},"toolbar":{"id":"2a375a31-6a55-4c9a-bb58-66ec6ddc0f09","type":"Toolbar"},"x_range":{"id":"08cd7b17-558d-4334-a368-c0a13ba7ff35","type":"DataRange1d"},"y_range":{"id":"b87ee092-acd1-4cc1-8e40-7955252bf3c3","type":"DataRange1d"}},"id":"15f7a887-8185-49ae-b22b-706b8d20307d","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"f735c3b6-3b6e-497f-a7d7-f3abc0f83e4c","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y","size"],"data":{"size":[10,20,30,40],"y":[2,5,8,12]}},"id":"a0d90090-0d70-48d8-88c4-8c4a0ad45610","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"a0d90090-0d70-48d8-88c4-8c4a0ad45610","type":"ColumnDataSource"},"glyph":{"id":"edbb8e07-7655-46d6-aad4-c8f6f6103ad4","type":"DiamondCross"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c09e7ba3-9876-4ded-8e80-bca81fdf2fe3","type":"DiamondCross"},"selection_glyph":null},"id":"3e11e8f1-b4dd-4073-a3b9-f17c6119d9bc","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"value":10},"y":{"field":"y"}},"id":"edbb8e07-7655-46d6-aad4-c8f6f6103ad4","type":"DiamondCross"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1c27d3e4-e079-4600-bae2-8d926d29cccd","type":"PanTool"},{"id":"8ba3f0f2-57a0-4375-8041-d962d0175982","type":"WheelZoomTool"},{"id":"5f946e03-a2fa-4365-89b4-26637d9eb357","type":"BoxZoomTool"},{"id":"340fc2ed-4b15-4ff9-bed3-a273afaa46f5","type":"SaveTool"},{"id":"85196820-d57c-412a-a7c1-864ec3ebc2b4","type":"ResetTool"},{"id":"4655bda9-e590-4de4-af7f-614def640098","type":"HelpTool"}]},"id":"2a375a31-6a55-4c9a-bb58-66ec6ddc0f09","type":"Toolbar"},{"attributes":{"plot":{"id":"15f7a887-8185-49ae-b22b-706b8d20307d","subtype":"Figure","type":"Plot"},"ticker":{"id":"5314c7dc-2ba6-49a0-9967-b11aaed7bba0","type":"BasicTicker"}},"id":"f7c847b2-72c3-4eb9-b8e5-9935d8a3716d","type":"Grid"},{"attributes":{"callback":null},"id":"08cd7b17-558d-4334-a368-c0a13ba7ff35","type":"DataRange1d"},{"attributes":{"formatter":{"id":"f735c3b6-3b6e-497f-a7d7-f3abc0f83e4c","type":"BasicTickFormatter"},"plot":{"id":"15f7a887-8185-49ae-b22b-706b8d20307d","subtype":"Figure","type":"Plot"},"ticker":{"id":"5314c7dc-2ba6-49a0-9967-b11aaed7bba0","type":"BasicTicker"}},"id":"f269bd27-b637-44ae-bcbc-066143e0a29a","type":"LinearAxis"},{"attributes":{"callback":null},"id":"b87ee092-acd1-4cc1-8e40-7955252bf3c3","type":"DataRange1d"},{"attributes":{},"id":"5314c7dc-2ba6-49a0-9967-b11aaed7bba0","type":"BasicTicker"},{"attributes":{},"id":"dc9987c2-c1dc-4cfb-9a08-50bca413da07","type":"BasicTicker"},{"attributes":{"overlay":{"id":"c36ed490-0015-4db0-a031-42187896644b","type":"BoxAnnotation"},"plot":{"id":"15f7a887-8185-49ae-b22b-706b8d20307d","subtype":"Figure","type":"Plot"}},"id":"5f946e03-a2fa-4365-89b4-26637d9eb357","type":"BoxZoomTool"},{"attributes":{"dimension":1," ...

# %% [markdown]
# # A scatter plot with different shapes
# By calling multiple glyph functions on the same figure object, we can overlay multiple data sets in the same figure.
#
# In this exercise, you will plot female literacy vs fertility for two different regions, Africa and Latin America. Each set of x and y data has been loaded separately for you as fertility_africa, female_literacy_africa, fertility_latinamerica, and female_literacy_latinamerica.
#
# Your job is to plot the Latin America data with the circle() glyph, and the Africa data with the x() glyph.
#
# figure has already been imported for you from bokeh.plotting.
#
# ### Instructions
# * Create the figure p with the figure() function. It has two parameters: x_axis_label and y_axis_label.
# * Add a circle glyph to the figure p using the function p.circle() where the inputs are the x and y data from Latin America: fertility_latinamerica and female_literacy_latinamerica.
# * Add an x glyph to the figure p using the function p.x() where the inputs are the x and y data from Africa: fertility_africa and female_literacy_africa.
# * The code to create, display, and specify the name of the output file has been written for you, so after adding the x glyph, hit 'Submit Answer' to view the figure.

# %%
# Create the figure: p
p = figure(x_axis_label='fertility', y_axis_label='female_literacy (% population)')

# Add a circle glyph to the figure p
p.circle(x=fertility_latinamerica, y=female_literacy_latinamerica)

# Add an x glyph to the figure p
p.x(x=fertility_africa, y=female_literacy_africa)

# Specify the name of the file#
# output_file('fert_lit_separate.html') This is how it would look outside of jupyter notebook.
output_notebook()

# Display the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="406d113d-71d3-4f1f-9ac5-8992551f2307">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="168e01cb-961b-40ab-843e-84c1c975ac5c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("168e01cb-961b-40ab-843e-84c1c975ac5c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("168e01cb-961b-40ab-843e-84c1c975ac5c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '168e01cb-961b-40ab-843e-84c1c975ac5c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"93818fda-73ef-436c-9f51-72d6f88aa0bf":{"roots":{"references":[{"attributes":{"overlay":{"id":"33e10e0f-399d-42f8-a4ad-dbe5f9ca51e6","type":"BoxAnnotation"},"plot":{"id":"d5ce4721-03bb-456f-97db-ad1556d38765","subtype":"Figure","type":"Plot"}},"id":"ccaea0c7-40b3-47e1-9feb-559b49760668","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"33e10e0f-399d-42f8-a4ad-dbe5f9ca51e6","type":"BoxAnnotation"},{"attributes":{},"id":"61347f93-bd70-4c89-a4de-ce0acb496055","type":"BasicTicker"},{"attributes":{"data_source":{"id":"96d6ee19-05d2-4b33-b16a-64907341f8d7","type":"ColumnDataSource"},"glyph":{"id":"5c12bc48-2fc8-4e29-8a01-882c1c00aabf","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c1281cc4-65fa-4ad0-9908-453463b2e80c","type":"Circle"},"selection_glyph":null},"id":"da0aa915-28f8-4038-b7c6-b915d7fdd381","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"d5ce4721-03bb-456f-97db-ad1556d38765","subtype":"Figure","type":"Plot"}},"id":"e2c7cade-6630-4d86-99ee-5a9f497ad5a2","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"d5ce4721-03bb-456f-97db-ad1556d38765","subtype":"Figure","type":"Plot"},"ticker":{"id":"61347f93-bd70-4c89-a4de-ce0acb496055","type":"BasicTicker"}},"id":"6202c27c-bcf6-42ad-8c35-0f1ba96aac61","type":"Grid"},{"attributes":{"callback":null},"id":"f27efd3e-fff7-4302-9795-c2fc8991d04a","type":"DataRange1d"},{"attributes":{},"id":"2f4bed52-9130-4a4c-af80-87d3f3ccfe94","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c1281cc4-65fa-4ad0-9908-453463b2e80c","type":"Circle"},{"attributes":{"data_source":{"id":"ea6501ad-4c60-4c7c-bf43-3a6c4e73a602","type":"ColumnDataSource"},"glyph":{"id":"2546e8c8-b3c8-423e-8bc5-58cce251b72d","type":"X"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8800ccda-0a82-40bd-8790-4918edba5af8","type":"X"},"selection_glyph":null},"id":"0ad38106-248c-4d51-83cc-505ac87e4256","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":""},"id":"3c1c0bdf-978b-43f5-81eb-9e89bbbac2e6","type":"Title"},{"attributes":{"plot":{"id":"d5ce4721-03bb-456f-97db-ad1556d38765","subtype":"Figure","type":"Plot"}},"id":"b550d3e4-9182-466e-a48c-ce4cac3ffdb6","type":"WheelZoomTool"},{"attributes":{},"id":"a9435bd4-a0c8-450e-81eb-906f61185588","type":"BasicTicker"},{"attributes":{"axis_label":"fertility","formatter":{"id":"2f4bed52-9130-4a4c-af80-87d3f3ccfe94","type":"BasicTickFormatter"},"plot":{"id":"d5ce4721-03bb-456f-97db-ad1556d38765","subtype":"Figure","type":"Plot"},"ticker":{"id":"a9435bd4-a0c8-450e-81eb-906f61185588","type":"BasicTicker"}},"id":"4d8fccdd-fed1-4d50-9704-2f1d0fb77152","type":"LinearAxis"},{"attributes":{"plot":{"id":"d5ce4721-03bb-456f-97db-ad1556d38765","subtype":"Figure","type":"Plot"}},"id":"986cd458-b29a-4e18-a6e8-a571ef82e30e","type":"HelpTool"},{"attributes":{"callback":null},"id":"4034490c-0171-4404-830d-96d2a19a8e7b","type":"DataRange1d"},{"attributes":{"axis_label":"female_literacy (% population)","formatter":{"id":"5f5ec5c3-d5f1-4356-89a6-47b953c28b6c","type":"BasicTickFormatter"},"plot":{"id":"d5ce4721-03bb-456f-97db-ad1556d38765","subtype":"Figure","type":"Plot"},"ticker":{"id":"61347f93-bd70-4c89-a4de-ce0acb496055","type":"BasicTicker"}},"id":"bc561934-9886-4329-9f94-57a800837ff6","type":"LinearAxis"},{"attributes":{"plot":{"id":"d5ce4721-03bb-456f-97db-ad1556d38765","subtype":"Figure","type":"Plot"},"ticker":{"id":"a9435bd4-a0c8-450e-81eb-906f61185588","type":"BasicTicker"}},"id":"7ea7d395-75fe-4e27-9b75-98f592bfb84b","type":"Grid"},{"attributes":{" ...

# %% [markdown]
# # Customizing your scatter plots
# The three most important arguments to customize scatter glyphs are color, size, and alpha. Bokeh accepts colors as hexadecimal strings, tuples of RGB values between 0 and 255, and any of the 147 CSS color names. Size values are supplied in screen space units with 100 meaning the size of the entire figure.
#
# The alpha parameter controls transparency. It takes in floating point numbers between 0.0, meaning completely transparent, and 1.0, meaning completely opaque.
#
# In this exercise, you'll plot female literacy vs fertility for Africa and Latin America as red and blue circle glyphs, respectively.
#
# ### Instructions
# * Using the Latin America data (fertility_latinamerica and female_literacy_latinamerica), add a blue * * circle glyph of size=10 and alpha=0.8 to the figure p. To do this, you will need to specify the color, size and alpha keyword arguments inside p.circle().
# * Using the Africa data (fertility_africa and female_literacy_africa), add a red circle glyph of size=10 and alpha=0.8 to the figure p.

# %% [markdown]
# ### Website link for CSS color chart
# http://www.colors.commutercreative.com/grid/

# %%
# Create the figure: p
p = figure(x_axis_label='fertility (children per woman)', y_axis_label='female_literacy (% population)')

# Add a blue circle glyph to the figure p
p.circle(fertility_latinamerica, female_literacy_latinamerica, color='blue', size=10, alpha=0.8)

# Add a red circle glyph to the figure p
p.circle(fertility_africa, female_literacy_africa, color='red', size=10, alpha=0.8)

# Specify the name of the file ...... output_file('fert_lit_separate_colors.html')
output_notebook()
# Display the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="713cc646-0440-4c9b-8e1d-3a483a96f662">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f3288ce8-6249-4574-8b51-e8cce87247b3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f3288ce8-6249-4574-8b51-e8cce87247b3");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f3288ce8-6249-4574-8b51-e8cce87247b3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f3288ce8-6249-4574-8b51-e8cce87247b3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2f3fb77d-a3df-4d31-97e8-8c254623c3ae":{"roots":{"references":[{"attributes":{"plot":{"id":"11a44108-cf44-4493-a390-39fe95a084f8","subtype":"Figure","type":"Plot"}},"id":"e509ebb1-5707-4a1b-8b70-2549f9ea3edb","type":"HelpTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"0f042e03-f795-4902-b9b7-e3e382aec1bb","type":"Circle"},{"attributes":{"plot":null,"text":""},"id":"023e051c-34b3-4b4d-94ac-3ce5222447d1","type":"Title"},{"attributes":{},"id":"0e16a29a-0de0-4c99-b628-f0c373c0edc0","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"55ef1ac8-8f9b-4f53-97d3-19acb8418296","type":"ColumnDataSource"},"glyph":{"id":"d0cae5ab-330d-48dd-8ef3-75591fe57e8f","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0f042e03-f795-4902-b9b7-e3e382aec1bb","type":"Circle"},"selection_glyph":null},"id":"f4e782b9-433d-4a57-9568-5303e1d8f02f","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"5000d285-c7fb-412a-aab3-c15641947be5","type":"DataRange1d"},{"attributes":{"below":[{"id":"1f0a93f5-1865-420b-a8ec-350885060da1","type":"LinearAxis"}],"left":[{"id":"0032d1f6-6247-46cc-a915-f574019a63d8","type":"LinearAxis"}],"renderers":[{"id":"1f0a93f5-1865-420b-a8ec-350885060da1","type":"LinearAxis"},{"id":"0a9e9d23-662c-4760-9afb-8bc41f2b6e18","type":"Grid"},{"id":"0032d1f6-6247-46cc-a915-f574019a63d8","type":"LinearAxis"},{"id":"8172f9fe-943a-426c-b593-05416b3ff7ed","type":"Grid"},{"id":"5fd99437-f77d-47a0-b415-4dc73c8a73c9","type":"BoxAnnotation"},{"id":"3323e4f9-b77d-417b-9a05-08570ed42344","type":"GlyphRenderer"},{"id":"f4e782b9-433d-4a57-9568-5303e1d8f02f","type":"GlyphRenderer"}],"title":{"id":"023e051c-34b3-4b4d-94ac-3ce5222447d1","type":"Title"},"tool_events":{"id":"7a0a6484-c618-496b-ba92-80dd2a779191","type":"ToolEvents"},"toolbar":{"id":"151f618f-0d33-4479-9243-6fabbd4086ff","type":"Toolbar"},"x_range":{"id":"5000d285-c7fb-412a-aab3-c15641947be5","type":"DataRange1d"},"y_range":{"id":"d44b6e8a-584c-4b9c-9a48-e815ea520b39","type":"DataRange1d"}},"id":"11a44108-cf44-4493-a390-39fe95a084f8","subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9e8db4cb-0612-45a2-8667-aef308f271cb","type":"PanTool"},{"id":"0df20b6f-3452-4fa7-8bb1-9c6fb6fced19","type":"WheelZoomTool"},{"id":"933e055c-1626-49c3-812f-32415cc5b3d5","type":"BoxZoomTool"},{"id":"8f5c7027-35eb-4783-a68a-8735cda1dc65","type":"SaveTool"},{"id":"8cecc5c1-c819-4783-b462-af4074d103cd","type":"ResetTool"},{"id":"e509ebb1-5707-4a1b-8b70-2549f9ea3edb","type":"HelpTool"}]},"id":"151f618f-0d33-4479-9243-6fabbd4086ff","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1.827,2.156,2.404,2.2230000000000003,2.53,2.498,1.926,4.018,2.513,1.505,2.612,3.3710000000000004,3.19,2.977,2.295,2.6830000000000003,1.943,2.516,2.089,2.362,1.6469999999999998,2.373,3.3710000000000004,1.732],"y":[90.2,91.5,93.4,97.7,84.6,94.9,98.7,68.7,81.7,99.8,88.3,86.0,83.5,93.5,81.4,77.9,96.2,92.8,98.5,90.8,98.2,88.4,96.5,98.0]}},"id":"515422b7-24f7-470b-846a-9c24669ca000","type":"ColumnDataSource"},{"attributes":{},"id":"7a0a6484-c618-496b-ba92-80dd2a779191","type":"ToolEvents"},{"attributes":{"plot":{"id":"11a44108-cf44-4493-a390-39fe95a084f8","subtype":"Figure","type":"Plot"}},"id":"0df20b6f-3452-4fa7-8bb1-9c6fb6fced19","type":"WheelZoomTool"},{"attributes":{},"id":"5196c124-a7ad-4fcd-8b9a-bc671ccf1fc1","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"65f131e0-c73e-4e5a-95da-484acab95367","type":"Circle"},{"attributes":{"callback":null},"id":"d44b6e8a-584c-4b9c-9a48-e815ea520b39","type":" ...
