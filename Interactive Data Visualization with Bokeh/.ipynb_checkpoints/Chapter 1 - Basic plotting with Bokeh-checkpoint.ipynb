# %% [markdown]
# # Interactive Data Visualization with Bokeh
# ##### Course Description
# Bokeh is an interactive data visualization library for Python (and other languages!) that targets modern web browsers for presentation. It can create versatile, data-driven graphics, and connect the full power of the entire Python data-science stack to rich, interactive visualizations.
#
# ### Chapter 1: Basic plotting with Bokeh
# An introduction to basic plotting with Bokeh. You will create your first plots, learn about different data formats Bokeh understands, and make visual customizations for selections and mouse hovering.

# %% [markdown]
# # A simple scatter plot
# In this example, you're going to make a scatter plot of female literacy vs fertility using data from the European Environmental Agency. This dataset highlights that countries with low female literacy have high birthrates. The x-axis data has been loaded for you as fertility and the y-axis data has been loaded as female_literacy.
#
# Your job is to create a figure, assign x-axis and y-axis labels, and plot female_literacy vs fertility using the circle glyph.
#
# After you have created the figure, in this exercise and the ones to follow, play around with it! Explore the different options available to you on the tab to the right, such as "Pan", "Box Zoom", and "Wheel Zoom". You can click on the question mark sign for more details on any of these tools.
#
# Note: You may have to scroll down to view the lower portion of the figure.
#
# ### Instructions
# * Import the figure function from bokeh.plotting, and the output_file and show functions from bokeh.io.
# * Create the figure p with figure(). It has two parameters: x_axis_label and y_axis_label.
# * Add a circle glyph to the figure p using the function p.circle() where the inputs are, in order, the x-axis data and y-axis data.
# * Use the output_file() function to specify the name 'fert_lit.html' for the output file.
# * Create and display the output file using show() and passing in the figure p.

# %%
fertility = [1.7690000000000001, 2.682, 2.077, 2.1319999999999997, 1.827, 3.872, 2.2880000000000003, 5.172999999999999, 1.393, 1.262, 2.156, 3.0260000000000002, 2.033, 1.324, 2.8160000000000003, 5.211, 2.1, 1.781, 1.8219999999999998, 5.9079999999999995, 1.881, 1.8519999999999999, 1.39, 2.281, 2.505, 1.224, 1.361, 1.4680000000000002, 2.404, 5.52, 4.058, 2.2230000000000003, 4.859, 1.2670000000000001, 2.342, 1.579, 6.254, 2.334, 3.9610000000000003, 6.505, 2.53, 2.823, 2.498, 2.248, 2.508, 3.04, 1.854, 4.22, 5.1, 4.967, 1.325, 4.513999999999999, 3.173, 2.3080000000000003, 4.62, 4.541, 5.6370000000000005, 1.926, 1.7469999999999999, 2.294, 5.841, 5.455, 7.069, 2.859, 4.018, 2.513, 5.405, 5.737, 3.363, 4.89, 1.385, 1.505, 6.081, 1.784, 1.3780000000000001, 1.45, 1.841, 1.37, 2.612, 5.329, 5.33, 3.3710000000000004, 1.281, 1.871, 2.153, 5.377999999999999, 4.45, 1.46, 1.436, 1.6119999999999999, 3.19, 2.752, 3.35, 4.01, 4.166, 2.642, 2.977, 3.415, 2.295, 3.0189999999999997, 2.6830000000000003, 5.165, 1.849, 1.8359999999999999, 2.5180000000000002, 2.43, 4.5280000000000005, 1.263, 1.885, 1.943, 1.899, 1.442, 1.953, 4.697, 1.5819999999999999, 2.025, 1.841, 5.011, 1.212, 1.5019999999999998, 2.516, 1.367, 2.089, 4.388, 1.854, 1.7480000000000002, 2.978, 2.1519999999999997, 2.362, 1.9880000000000002, 1.426, 3.29, 3.264, 1.436, 1.393, 2.822, 4.968999999999999, 5.659, 3.24, 1.693, 1.6469999999999998, 2.36, 1.7919999999999998, 3.45, 1.516, 2.233, 2.563, 5.2829999999999995, 3.885, 0.966, 2.373, 2.6630000000000003, 1.251, 2.052, 3.3710000000000004, 2.093, 2.0, 3.883, 3.852, 3.718, 1.732, 3.928]
fertility_latinamerica = [1.827, 2.156, 2.404, 2.2230000000000003, 2.53, 2.498, 1.926, 4.018, 2.513, 1.505, 2.612, 3.3710000000000004, 3.19, 2.977, 2.295, 2.6830000000000003, 1.943, 2.516, 2.089, 2.362, 1.6469999999999998, 2.373, 3.3710000000000004, 1.732]
female_literacy_latinamerica = [90.2, 91.5, 93.4, 97.7, 84.6, 94.9, 98.7, 68.7, 81.7, 99.8, 88.3, 86.0, 83.5, 93.5, 81.4, 77.9, 96.2, 92.8, 98.5, 90.8, 98.2, 88.4, 96.5, 98.0]

# %%
# Import figure from bokeh.plotting
from bokeh.plotting import figure

# Import output_file and show from bokeh.io  NOTE: output_notebook is for Jupyter notebooks
from bokeh.io import output_notebook, show

# Create the figure: p
p = figure(x_axis_label='fertility (children per woman)', y_axis_label='female_literacy (% population)')

# Add a circle glyph to the figure p
p.circle(fertility, female_literacy)
# Look below for additional shapes to plot. Look at the Markers section.

# Call the output_file() function and specify the name of the file
output_notebook()

# Display the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="57e86f72-9d02-4ea5-aefe-58f539432327">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c961b4c9-6b16-4367-aeb8-7f888a02e88c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c961b4c9-6b16-4367-aeb8-7f888a02e88c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c961b4c9-6b16-4367-aeb8-7f888a02e88c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c961b4c9-6b16-4367-aeb8-7f888a02e88c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1e28d827-fa87-490b-9e19-b58fa0014d50":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"90043d2c-ace7-4d23-a0af-52ed2d3f0c2e","type":"Circle"},{"attributes":{"axis_label":"female_literacy (% population)","formatter":{"id":"41d3ccb9-6883-49a0-a048-4d9eb405c8b5","type":"BasicTickFormatter"},"plot":{"id":"a6a0eb05-a7b2-4b10-9932-4391bd9791e5","subtype":"Figure","type":"Plot"},"ticker":{"id":"4a43b9a3-d160-4731-aca9-669133d7a07c","type":"BasicTicker"}},"id":"6c7fcc8a-01b8-4557-a152-09be6e02fe8b","type":"LinearAxis"},{"attributes":{"plot":{"id":"a6a0eb05-a7b2-4b10-9932-4391bd9791e5","subtype":"Figure","type":"Plot"}},"id":"dde8e247-ff76-4860-b30e-99778197d248","type":"PanTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"dde8e247-ff76-4860-b30e-99778197d248","type":"PanTool"},{"id":"1f6d208d-f22d-4990-9649-224f17692bc0","type":"WheelZoomTool"},{"id":"e063f95d-7452-4861-a4ce-61944a261b07","type":"BoxZoomTool"},{"id":"b9777b83-56fd-43f9-ba4b-5e71aa4f471b","type":"SaveTool"},{"id":"092f7748-358e-464d-b8b0-5b9f039d77e0","type":"ResetTool"},{"id":"3104f2fb-9922-4e03-bb4c-55b1af1a1cf1","type":"HelpTool"}]},"id":"41834a4b-d19c-40ad-b1ff-a2861c89f45a","type":"Toolbar"},{"attributes":{"callback":null},"id":"01e46a88-b8bd-400e-bdff-4baf2f0f3818","type":"DataRange1d"},{"attributes":{"axis_label":"fertility (children per woman)","formatter":{"id":"5851f6c9-11f4-4cc5-a16c-5fb31cf385aa","type":"BasicTickFormatter"},"plot":{"id":"a6a0eb05-a7b2-4b10-9932-4391bd9791e5","subtype":"Figure","type":"Plot"},"ticker":{"id":"456483d5-db38-4e0e-b8c6-736f4ce0985e","type":"BasicTicker"}},"id":"a5f3b217-57cc-4773-af9a-f3283ce3f47c","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"8de36eea-6c12-43d1-9c29-e5e5c049b96d","type":"Title"},{"attributes":{"plot":{"id":"a6a0eb05-a7b2-4b10-9932-4391bd9791e5","subtype":"Figure","type":"Plot"},"ticker":{"id":"456483d5-db38-4e0e-b8c6-736f4ce0985e","type":"BasicTicker"}},"id":"5680fe5d-a18a-4731-81c1-f3f355a455a7","type":"Grid"},{"attributes":{},"id":"456483d5-db38-4e0e-b8c6-736f4ce0985e","type":"BasicTicker"},{"attributes":{"plot":{"id":"a6a0eb05-a7b2-4b10-9932-4391bd9791e5","subtype":"Figure","type":"Plot"}},"id":"1f6d208d-f22d-4990-9649-224f17692bc0","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"954bd919-4686-4cce-a632-98148b46b98a","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"a6a0eb05-a7b2-4b10-9932-4391bd9791e5","subtype":"Figure","type":"Plot"},"ticker":{"id":"4a43b9a3-d160-4731-aca9-669133d7a07c","type":"BasicTicker"}},"id":"582ad9ce-9b59-4e3d-a737-3c0fcf51f6d3","type":"Grid"},{"attributes":{},"id":"4a43b9a3-d160-4731-aca9-669133d7a07c","type":"BasicTicker"},{"attributes":{"overlay":{"id":"954bd919-4686-4cce-a632-98148b46b98a","type":"BoxAnnotation"},"plot":{"id":"a6a0eb05-a7b2-4b10-9932-4391bd9791e5","subtype":"Figure","type":"Plot"}},"id":"e063f95d-7452-4861-a4ce-61944a261b07","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"a6a0eb05-a7b2-4b10-9932-4391bd9791e5","subtype":"Figure","type":"Plot"}},"id":"b9777b83-56fd-43f9-ba4b-5e71aa4f471b","type":"SaveTool"},{"attributes":{"plot":{"id":"a6a0eb05-a7b2-4b10-9932-4391bd9791e5","subtype":"Figure","type":"Plot"}},"id":"3104f2fb-9922-4e03-bb4c-55b1af1a1cf1","type":"HelpTool"},{"attributes":{},"id":"5851f6c9-11f4-4cc5-a16c-5fb31cf385aa","type":"BasicTickFormatter"},{"attributes":{},"id":"1b839025-ae5d-441c-8c25-c6a40884215e","type":"ToolEvents"},{"attributes":{"below":[{"id":"a5f3b217-57cc-4773-af9a-f3283c ...

# %% [markdown]
# ### *Markers*
# * asterisk()
# * circle()
# * circle_cross()
# * circle_x()
# * cross()
# * diamond()
# * diamond_cross()
# * inverted_triangle()
# * square()
# * square_cross()
# * square_x()
# * triangle()
# * x()

# %%
# Glyph properties
# ● Lists, arrays, sequences of values
# ● Single fixed values
plot = figure()
plot.diamond_cross(x=10, y=[2,5,8,12], size=[10,20,30,40])
output_notebook()
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="928f8189-563b-4e61-9e9d-144ba446f76b">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5b945a7b-bf9f-48e6-89ec-daabc0c66614"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5b945a7b-bf9f-48e6-89ec-daabc0c66614");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5b945a7b-bf9f-48e6-89ec-daabc0c66614");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5b945a7b-bf9f-48e6-89ec-daabc0c66614' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e377e7e3-701a-4a5d-a5b9-190724faf3d1":{"roots":{"references":[{"attributes":{"plot":{"id":"0778fb4d-e4e1-4f69-b416-55c9e1f0ad65","subtype":"Figure","type":"Plot"}},"id":"1cd0bcc8-6eea-4de8-8467-74351785dc81","type":"HelpTool"},{"attributes":{"callback":null},"id":"6d83432a-651c-4fc5-a7f2-9f56956096ba","type":"DataRange1d"},{"attributes":{"data_source":{"id":"002441c6-1bb2-4c5b-854c-a591dbef3391","type":"ColumnDataSource"},"glyph":{"id":"43ed9fc9-8513-4aad-a459-06169e8d739e","type":"DiamondCross"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7748341c-74e4-4336-8190-de8bf6b3199d","type":"DiamondCross"},"selection_glyph":null},"id":"ff93cefc-567a-4142-a065-a168191614a1","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"aaadd208-880d-4002-acf6-2cb594dfa1fb","type":"LinearAxis"}],"left":[{"id":"241c5993-760e-4edb-8dc5-d2173add1327","type":"LinearAxis"}],"renderers":[{"id":"aaadd208-880d-4002-acf6-2cb594dfa1fb","type":"LinearAxis"},{"id":"40e9e4b1-02b3-4760-82a3-a5b2d8976db6","type":"Grid"},{"id":"241c5993-760e-4edb-8dc5-d2173add1327","type":"LinearAxis"},{"id":"773be3bc-fb0c-4570-8af6-8c9e46bd8c12","type":"Grid"},{"id":"4f6acb68-2335-4ddb-8d9a-4570ed748534","type":"BoxAnnotation"},{"id":"ff93cefc-567a-4142-a065-a168191614a1","type":"GlyphRenderer"}],"title":{"id":"102e16a0-4762-467f-aedc-dae6f3748a9e","type":"Title"},"tool_events":{"id":"2715302c-b762-4a6c-9eec-548b1b158cbd","type":"ToolEvents"},"toolbar":{"id":"2fdb53e3-a754-4e7a-a4a6-0b9a4d72acef","type":"Toolbar"},"x_range":{"id":"6d83432a-651c-4fc5-a7f2-9f56956096ba","type":"DataRange1d"},"y_range":{"id":"f29948a2-894e-48e9-9ab7-39aee7d02226","type":"DataRange1d"}},"id":"0778fb4d-e4e1-4f69-b416-55c9e1f0ad65","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"2715302c-b762-4a6c-9eec-548b1b158cbd","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"6278a630-874e-44d4-9414-ea9b041a3496","type":"PanTool"},{"id":"07a231f0-c998-4f79-bda1-edfa2166b107","type":"WheelZoomTool"},{"id":"f20d2398-863c-4eb8-9493-ac77d74900e1","type":"BoxZoomTool"},{"id":"0a52f7f9-c609-4e37-86ab-d6dca7c44b80","type":"SaveTool"},{"id":"c6a7c5a1-7c82-44ab-aa08-96ba3050efe3","type":"ResetTool"},{"id":"1cd0bcc8-6eea-4de8-8467-74351785dc81","type":"HelpTool"}]},"id":"2fdb53e3-a754-4e7a-a4a6-0b9a4d72acef","type":"Toolbar"},{"attributes":{},"id":"7f243282-a1fe-4e5f-a27c-9575deefd28c","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y","size"],"data":{"size":[10,20,30,40],"y":[2,5,8,12]}},"id":"002441c6-1bb2-4c5b-854c-a591dbef3391","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"4f6acb68-2335-4ddb-8d9a-4570ed748534","type":"BoxAnnotation"},"plot":{"id":"0778fb4d-e4e1-4f69-b416-55c9e1f0ad65","subtype":"Figure","type":"Plot"}},"id":"f20d2398-863c-4eb8-9493-ac77d74900e1","type":"BoxZoomTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"value":10},"y":{"field":"y"}},"id":"43ed9fc9-8513-4aad-a459-06169e8d739e","type":"DiamondCross"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"value":10},"y":{"field":"y"}},"id":"7748341c-74e4-4336-8190-de8bf6b3199d","type":"DiamondCross"},{"attributes":{"plot":{"id":"0778fb4d-e4e1-4f69-b416-55c9e1f0ad65","subtype":"Figure","type":"Plot"}},"id":"0a52f7f9-c609-4e37-86ab-d6dca7c44b80","type":"SaveTool"},{"attributes":{"plot":null,"text":""},"id":"102e16a0-4762-467f-aedc-dae6f3748a9e","type":"Title"},{"attributes":{"plot":{"id":"0778fb4d-e4e1-4f69-b416-55c9e1f0ad65","subtype":"Figure","type":"Plot"}},"id":"6278a630-874e-44d4-9414-ea9b041a3496","type":"PanTool"},{"attributes":{"formatter":{"id":"a5fd6296-c5fd-4c43-91a0-57bab793369b","type":"BasicTickFormatter"},"plot":{"id":"0778fb4d-e4e1-4f69-b416-55c9e1f0ad65"," ...

# %% [markdown]
# # A scatter plot with different shapes
# By calling multiple glyph functions on the same figure object, we can overlay multiple data sets in the same figure.
#
# In this exercise, you will plot female literacy vs fertility for two different regions, Africa and Latin America. Each set of x and y data has been loaded separately for you as fertility_africa, female_literacy_africa, fertility_latinamerica, and female_literacy_latinamerica.
#
# Your job is to plot the Latin America data with the circle() glyph, and the Africa data with the x() glyph.
#
# figure has already been imported for you from bokeh.plotting.
#
# ### Instructions
# * Create the figure p with the figure() function. It has two parameters: x_axis_label and y_axis_label.
# * Add a circle glyph to the figure p using the function p.circle() where the inputs are the x and y data from Latin America: fertility_latinamerica and female_literacy_latinamerica.
# * Add an x glyph to the figure p using the function p.x() where the inputs are the x and y data from Africa: fertility_africa and female_literacy_africa.
# * The code to create, display, and specify the name of the output file has been written for you, so after adding the x glyph, hit 'Submit Answer' to view the figure.

# %%
# Create the figure: p
p = figure(x_axis_label='fertility', y_axis_label='female_literacy (% population)')

# Add a circle glyph to the figure p
p.circle
type":"BasicTicker"},{"attributes":{"callback":null},"id":"f9d76e96-4f97-4428-b446-55d880dc6c50","type":"DataRange1d"},{"attributes":{"axis_label":"female_literacy (% population)","formatter":{"id":"79706a2a-39f1-4c22-9621-7b5eeef9a3b3","type":"BasicTickFormatter"},"plot":{"id":"909c2f8c-6ab1-48d8-9d5f-7f4c7eb19018","subtype":"Figure","type":"Plot"},"ticker":{"id":"cc2741d3-854d-489c-b442-dc110e125aad","type":"BasicTicker"}},"id":"651b4935-eb39-41fe-ba3e-11879dd155a3","type":"LinearAxis"},{"attributes":{},"id":"50558d0f-26e2-4143-b65c-50a24c397cfa","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"909c2f8c-6ab1-48d8-9d5f-7f4c7eb19018","subtype":"Figure","type":"Plot"},"ticker":{"id":"cc2741d3-854d-489c-b442-dc110e125aad","type":"BasicTicker"}},"id":"8129545b-a809-475b-994a-d3324774bdec","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"def477b1-78eb-450c-a01d-00b1d8989ab2","type":"Circle"},{"attributes":{},"id":"bd4ca6df-78f2-4672-8ee9-23945755fa49","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1285aa5c-ffc6-4513-aead-c5418602c9bc","type":"PanTool"},{"id":"8abfe51b-5191-4ec3-a309-e4a48777375d","type":"WheelZoomTool"},{"id":"c701410d-70ef-4090-a338-357fac21c9fb","type":"BoxZoomTool"},{"id":"318f2b0b-4b9d-489a-8b89-9f852da20a29","type":"SaveTool"},{"id":"ca168df1-b111-4d8b-99d4-a30e0ad1b4ca","type":"ResetTool"},{"id":"4c3757b8-c8a8-4b62-93fb-4fab1d592a7b","type":"HelpTool"}]},"id":"6d25be2f-dd13-4c53-8de9-1d4286aaf87d","type":"Toolbar"},{"attri ...

# %% [markdown]
# # Customizing your scatter plots
# The three most important arguments to customize scatter glyphs are color, size, and alpha. Bokeh accepts colors as hexadecimal strings, tuples of RGB values between 0 and 255, and any of the 147 CSS color names. Size values are supplied in screen space units with 100 meaning the size of the entire figure.
#
# The alpha parameter controls transparency. It takes in floating point numbers between 0.0, meaning completely transparent, and 1.0, meaning completely opaque.
#
# In this exercise, you'll plot female literacy vs fertility for Africa and Latin America as red and blue circle glyphs, respectively.
#
# ### Instructions
# * Using the Latin America data (fertility_latinamerica and female_literacy_latinamerica), add a blue * * circle glyph of size=10 and alpha=0.8 to the figure p. To do this, you will need to specify the color, size and alpha keyword arguments inside p.circle().
# * Using the Africa data (fertility_africa and female_literacy_africa), add a red circle glyph of size=10 and alpha=0.8 to the figure p.

# %% [markdown]
# ### Website link for CSS color chart
# http://www.colors.commutercreative.com/grid/

# %%
# Create the figure: p
p = figure(x_axis_label='fertility (children per woman)', y_axis_label='female_literacy (% population)')

# Add a blue circle glyph to the figure p
p.circle(fertility_latinamerica, female_literacy_latinamerica, color='blue', size=10, alpha=0.8)

# Add a red circle glyph to the figure p
p.circle(fertility_africa, female_literacy_africa, color='red', size=10, alpha=0.8)

# Specify the name of the file ...... output_file('fert_lit_separate_colors.html')
output_notebook()
# Display the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7230118f-a05d-449d-baf3-05fd3eeed221">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5a926c70-f5e1-485a-905c-84a4c7791eac"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5a926c70-f5e1-485a-905c-84a4c7791eac");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5a926c70-f5e1-485a-905c-84a4c7791eac");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5a926c70-f5e1-485a-905c-84a4c7791eac' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e7489854-e70f-4dd4-9052-4a25cd40edd3":{"roots":{"references":[{"attributes":{},"id":"9a8a3cb1-c876-4136-a2f5-5bb27ab9c8ff","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"